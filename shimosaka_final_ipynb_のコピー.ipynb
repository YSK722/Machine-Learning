# %% [markdown]
# <a href="https://colab.research.google.com/github/YSK722/Machine-Learning/blob/main/shimosaka_final_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# requirements
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cv

# %% [markdown]
# # Datasets

# %%
# dataset 1
np.random.seed(123)
n = 100
x_d1 = 3 * (np.random.rand(n, 2)-0.5)
radius = x_d1[:,0]**2 + x_d1[:,1]**2
y_d1 = (radius > 0.7 + 0.1 * np.random.randn(n)) &( radius < 2.2 + 0.1 * np.random.randn(n))
y_d1 = 2 * y_d1 -1

plt.plot(x_d1[y_d1 < 0, 0],  x_d1[y_d1 < 0, 1], 'bs')
plt.plot(x_d1[y_d1 > 0, 0],  x_d1[y_d1 > 0, 1], 'ro')

# %%
# dataset 2
n = 4000
omega = np.random.randn()
noise = 0.8 * np.random.randn(n)

x_d2 = np.random.randn(n, 2) + 0
y_d2 = 2 * (omega * x_d2[:,0] + x_d2[:,1] + noise > 0) - 1

plt.plot(np.extract(y_d2>0,x_d2[:,0]),np.extract(y_d2>0,x_d2[:,1]), 'x')
plt.plot(np.extract(y_d2<0,x_d2[:,0]),np.extract(y_d2<0,x_d2[:,1]), 'o')

# %%
#dataset3
np.random.seed(1234)
m = 20
n = 40
r = 2
A = np.dot(np.random.rand(m, r), np.random.rand(r, n)).flatten()
ninc = 100
Q = np.random.permutation(m * n)[:ninc]
A[Q] = None
A = A.reshape(m, n)

plt.pcolor(A, cmap=plt.cm.plasma)

# %%
# dataset 4
n = 200
x_d4 = 3 * (np.random.rand(n, 4) - 0.5)
y_d4 = (2 * x_d4[:, 0] - 1 * x_d4[:,1] + 0.5 + 0.5 * np.random.randn(n)) > 0
y_d4 = 2 * y_d4 -1

# %%
# dataset 5
n = 200
x_d5 = 3 * (np.random.rand(n, 4) - 0.5)
W = np.array([[ 2,  -1, 0.5,],
              [-3,   2,   1,],
              [ 1,   2,   3]])
y_d5 = np.argmax(np.dot(np.hstack([x_d5[:,:2], np.ones((n, 1))]), W.T)
                        + 0.5 * np.random.randn(n, 3), axis=1)

# %%
# dataset 6
d_d6 = 200
n_d6 = 180

# we consider 5 groups where each group has 40 attributes
groupSize = 5
attrSize = 40
g_d6 = np.arange(groupSize*attrSize).reshape(groupSize,-1)

x_d6 = np.random.randn(n_d6, d_d6)
noise_d6 = 0.5

# we consider feature in group 1 and group 2 is activated.
w_d6 = np.vstack([20 * np.random.randn(80, 1),
                 np.zeros((120, 1)),
                 5 * np.random.rand()])
x_d6_tilde = np.hstack([x_d6, np.ones((n_d6, 1))])
y_d6 = np.dot(x_d6_tilde, w_d6) + noise_d6 * np.random.randn(n_d6, 1)

# %% [markdown]
# # Problem 1

# %%
# requirement
import numpy as np
import matplotlib.pyplot as plt
import cvxpy

# %%
loss_hist_batch = [] # to store the history of loss J(w_t)

# implement batch steepest gradient method here
def cost(w, x, y, lmd):
    rslt = 0
    for i in range(len(y)):
        rslt += np.log(1 + np.exp(-y[i]*w.T.dot(x[i])))
    return rslt + lmd*w.T.dot(w)


def grad(w, x, y, lmd):
    rslt = np.array([0] * len(x[0]))
    for i in range(len(y)):
        rslt = rslt + np.exp(-y[i]*w.T.dot(x[i]))*(-y[i]*x[i])/(1 + np.exp(-y[i]*w.T.dot(x[i])))
    return rslt + 2*lmd*w


lmd = 0.01
it = 100
w = np.array([0] * 4)

lr = 1.0 / np.abs(max(np.linalg.eigvals(len(x_d4[0]) * x_d4.dot(x_d4.T) + 2*lmd*np.eye(len(x_d4)))))
print(f'learning rate is {lr}')

loss_hist_batch.append(cost(w, x_d4, y_d4, lmd))
for i in range(it):
    w = w - lr * grad(w, x_d4, y_d4, lmd)
    loss_hist_batch.append(cost(w, x_d4, y_d4, lmd))
# Out:
# learning rate is 0.001222545152849778

# %%
loss_hist_newton = [] # to store the history of loss J(w_t)

# implement Newton based method here
def grad2(w, x, y, lmd):
    rslt = np.array([[0] * len(x[0])] * len(x[0]))
    for i in range(len(y)):
        rslt = rslt + np.exp(-y[i]*w.T.dot(x[i]))*(y[i]**2*x[i].dot(x[i].T))/(1 + np.exp(-y[i]*w.T.dot(x[i])))**2
    return rslt + 2*lmd*np.eye(len(x[0]))

w = np.array([0] * 4)

loss_hist_newton.append(cost(w, x_d4, y_d4, lmd))
for i in range(it):
    w = w - lr * np.linalg.inv(grad2(w, x_d4, y_d4, lmd)).dot((grad(w, x_d4, y_d4, lmd)))
    loss_hist_newton.append(cost(w, x_d4, y_d4, lmd))

# %%
# plot the result
opt = loss_hist_newton[-1]
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Distance')
plt.plot(np.abs(loss_hist_batch[:51] - opt), label='gradient descent')
plt.plot(np.abs(loss_hist_newton[:51] - opt), label='Newton')
plt.legend()

# %% [markdown]
# # Problem 2

# %%
# requirement
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cv

# prepare dataset
np.random.seed(3846)
n = 40
omega = np.random.randn()
noise = 0.8 * np.random.randn(n)

x = np.random.randn(n, 2) + 0
y = 2 * (omega * x[:,0] + x[:,1] + noise > 0) - 1

plt.plot(np.extract(y>0,x[:,0]),np.extract(y>0,x[:,1]), 'x')
plt.plot(np.extract(y<0,x[:,0]),np.extract(y<0,x[:,1]), 'o')

# %%
# condition
A = np.array([[  3, 0.5],
              [0.5,   1]])
mu = np.array([[1],
               [2]])

# %%
w_hat_lam = []
w_hat = []
lams = np.arange(0, 10, 0.001)

def cost(w, mu, lam):
    return (w - mu).T.dot(A).dot(w - mu)[0][0] / 2 + lasso(w, lam)

def lasso(z, lam):
    return lam * np.sum(np.abs(z))

def h(w, z):
    return np.sum(np.abs((w - z)**2))

def prox(w, gamma, eta, mu, lam):
    prox = np.array([[0], [0]])
    w = w - eta * grad(w, mu, lam)
    thresh = gamma * lam
    for i in range(len(w)):
        if w[i][0] >= thresh:
            prox[i][0] = w[i][0] - thresh
        elif w[i][0] <= -thresh:
            prox[i][0] = w[i][0] + thresh
    return prox

def grad(w, mu, lam):
    return (A + A.T).dot(w - mu) / 2

it = 100
eta = 1.0 / np.abs(max(np.linalg.eigvals(A)))
(u, l, v) = np.linalg.svd(x)
gamma = 1.0 / max(l.real*l.real)

for lam in lams:
    ### implement PG ###
    w= np.array([[0], [0]])
    if lam == 0.01:
        w_hat.append(cost(w, mu, lam))
    for i in range(it):
        w = prox(w, gamma, eta, mu, lam)
        z = w
        if lam == 0.01:
            w_hat.append(cost(w, mu, lam))
    w_hat_lam.append(np.abs(cost(w, mu, lam)))
    ###
opt = w_hat_lam[17]

# %%
plt.title('λ=0.01')
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Distance')
plt.plot(np.abs(w_hat[:51] - opt))

# %%
plt.yscale('log')
plt.xlabel('Lambda')
plt.ylabel('Distance')
plt.plot(lams, np.abs(w_hat_lam - opt))
plt.legend

# %%
w_hat_lam_new = []
A_new = np.array([[300, 0.5],
                    [0.5,   1]])

def cost_new(w, mu, lam):
    return (w - mu).T.dot(A_new).dot(w - mu)[0][0] / 2 + lasso(w, lam)

def grad_new(w, mu, lam):
    return (A_new + A_new.T).dot(w - mu) / 2

def prox_new(w, gamma, eta, mu, lam):
    prox = np.array([[0], [0]])
    w = w - eta * grad_new(w, mu, lam)
    thresh = gamma * lam
    for i in range(len(w)):
        if w[i][0] >= thresh:
            prox[i][0] = w[i][0] - thresh
        elif w[i][0] <= -thresh:
            prox[i][0] = w[i][0] + thresh
    return prox

lam = 0.01
eta = 1.0 / np.abs(max(np.linalg.eigvals(A_new)))
w = x[0]
w_hat_lam_new.append(np.abs(cost_new(w, mu, lam)))
for i in range(it):
    w = prox_new(w, gamma, eta, mu, lam)
    w_hat_lam_new.append(np.abs(cost_new(w, mu, lam)))
opt = w_hat_lam_new[-1]

plt.title(f'λ={lam}')
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Distance')
plt.plot(np.abs(w_hat_lam_new[:51] - opt), label='standard PG')
plt.legend()

# %% [markdown]
# ## example of group lasso (using dataset 6)

# %%
import cvxpy as cv
import matplotlib.pyplot as plt

def mldivide(A, b):
  piA = np.linalg.pinv(A)
  x = np.dot(piA, b)
  return x

# run the cell which preparing dataset 6 before run this cell
y = y_d6
x_tilde = x_d6_tilde
w = w_d6
noise = noise_d6
n = n_d6
d = d_d6
g = g_d6

lam = 1.0
wridge = mldivide(np.dot(x_tilde.T, x_tilde) + lam * np.eye(d+1),
                  np.dot(x_tilde.T, y))

# cvx
west = cv.Variable((d+1,1))
obj_fn = \
  0.5 / n * cv.quad_form(x_tilde * west - y, np.eye(x_tilde.shape[0])) + \
  lam * (cv.norm(west[g[0]], 2.0) + \
         cv.norm(west[g[1]], 2.0) + \
         cv.norm(west[g[2]], 2.0) + \
         cv.norm(west[g[3]], 2.0) + \
         cv.norm(west[g[4]], 2.0) )

objective = cv.Minimize(obj_fn)
constraints = []

prob = cv.Problem(objective, constraints)
result = prob.solve(solver=cv.CVXOPT)

# test
x_test = np.random.randn(n, d)
x_test_tilde = np.hstack([x_test, np.ones((n, 1))])
y_test = np.dot(x_test_tilde, w) + noise * np.random.randn(n, 1)
y_pred = np.dot(x_test_tilde, west.value)
print(np.mean((y_pred - y_test)**2))
# Out:
# 8.659234266599729

# %%
plt.plot(west.value[0:d], 'r-o', markersize=1.5, linewidth=0.5)
plt.plot(w, 'b-*', markersize=1.5, linewidth=0.5)
plt.plot(wridge, 'g-+', markersize=1.5, linewidth=0.5)

# %%
plt.plot(y_test, y_pred, 'bs', markersize=1)

# %%
print('carinality of w hat: %d'%sum(np.abs(west.value) < 0.01))
print('carinality of w ground truth: %d'%sum(np.abs(w) < 0.01))
# Out:
# carinality of w hat: 120
# carinality of w ground truth: 120
